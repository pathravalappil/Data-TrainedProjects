# %%
import pandas as pd

# %%
import numpy as np

# %%
df = pd.read_csv(" myexcel.csv")
df
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25  06-Feb     180
# 1      Jae Crowder  Boston Celtics      99       SF   25  06-Jun     235
# 2     John Holland  Boston Celtics      30       SG   27  06-May     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22  06-May     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  06-Oct     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26  06-Mar     203
# 454      Raul Neto       Utah Jazz      25       PG   24  06-Jan     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26  07-Mar     256
# 456    Jeff Withey       Utah Jazz      24        C   26     7-0     231
# 457       Priyanka       Utah Jazz      34        C   25  07-Mar     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 453    False
# 454    False
# 455    False
# 456    False
# 457    False
# Length: 458, dtype: bool

# %%
df.drop_duplicates(inplace = True)
df
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25  06-Feb     180
# 1      Jae Crowder  Boston Celtics      99       SF   25  06-Jun     235
# 2     John Holland  Boston Celtics      30       SG   27  06-May     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22  06-May     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  06-Oct     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26  06-Mar     203
# 454      Raul Neto       Utah Jazz      25       PG   24  06-Jan     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26  07-Mar     256
# 456    Jeff Withey       Utah Jazz      24        C   26     7-0     231
# 457       Priyanka       Utah Jazz      34        C   25  07-Mar     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
df["Salary"].fillna(950000,inplace=True)
df
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25  06-Feb     180
# 1      Jae Crowder  Boston Celtics      99       SF   25  06-Jun     235
# 2     John Holland  Boston Celtics      30       SG   27  06-May     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22  06-May     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  06-Oct     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26  06-Mar     203
# 454      Raul Neto       Utah Jazz      25       PG   24  06-Jan     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26  07-Mar     256
# 456    Jeff Withey       Utah Jazz      24        C   26     7-0     231
# 457       Priyanka       Utah Jazz      34        C   25  07-Mar     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
x = df["Weight"].mean()
df["Weight"].fillna(x,inplace=True)
df
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25  06-Feb     180
# 1      Jae Crowder  Boston Celtics      99       SF   25  06-Jun     235
# 2     John Holland  Boston Celtics      30       SG   27  06-May     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22  06-May     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  06-Oct     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26  06-Mar     203
# 454      Raul Neto       Utah Jazz      25       PG   24  06-Jan     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26  07-Mar     256
# 456    Jeff Withey       Utah Jazz      24        C   26     7-0     231
# 457       Priyanka       Utah Jazz      34        C   25  07-Mar     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
df["College"].fillna("Geogia State" , inplace=True)
df
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25  06-Feb     180
# 1      Jae Crowder  Boston Celtics      99       SF   25  06-Jun     235
# 2     John Holland  Boston Celtics      30       SG   27  06-May     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22  06-May     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  06-Oct     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26  06-Mar     203
# 454      Raul Neto       Utah Jazz      25       PG   24  06-Jan     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26  07-Mar     256
# 456    Jeff Withey       Utah Jazz      24        C   26     7-0     231
# 457       Priyanka       Utah Jazz      34        C   25  07-Mar     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
X = df["Age"].mean()
df["Age"].fillna(X,inplace=True)
df
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25  06-Feb     180
# 1      Jae Crowder  Boston Celtics      99       SF   25  06-Jun     235
# 2     John Holland  Boston Celtics      30       SG   27  06-May     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22  06-May     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  06-Oct     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26  06-Mar     203
# 454      Raul Neto       Utah Jazz      25       PG   24  06-Jan     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26  07-Mar     256
# 456    Jeff Withey       Utah Jazz      24        C   26     7-0     231
# 457       Priyanka       Utah Jazz      34        C   25  07-Mar     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
from mataplotlib import pyplot

# %%
import mataplotlib.pyplot as plt

# %%
import numpy as np

# %%
df["Height"]=np.random.uniform(150,180,size = len(df))
df
# Out:
#               Name            Team  Number Position  Age      Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25  178.235976     180
# 1      Jae Crowder  Boston Celtics      99       SF   25  156.056916     235
# 2     John Holland  Boston Celtics      30       SG   27  173.874222     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22  158.531511     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  157.612146     231
# ..             ...             ...     ...      ...  ...         ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26  166.117884     203
# 454      Raul Neto       Utah Jazz      25       PG   24  166.122656     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26  175.377431     256
# 456    Jeff Withey       Utah Jazz      24        C   26  157.371233     231
# 457       Priyanka       Utah Jazz      34        C   25  165.128651     231
#
#                College     Salary
# ...

# %% [markdown]
# # 1.Hoe many are there in each Team and the percentage spliting with respect to the total employees .

# %%
uni = df.groupby("Team")["Name"].nunique()
uni
# Out:
# Team
# Atlanta Hawks             15
# Boston Celtics            15
# Brooklyn Nets             15
# Charlotte Hornets         15
# Chicago Bulls             15
# Cleveland Cavaliers       15
# Dallas Mavericks          15
# Denver Nuggets            15
# Detroit Pistons           15
# Golden State Warriors     15
# Houston Rockets           15
# Indiana Pacers            15
# Los Angeles Clippers      15
# Los Angeles Lakers        15
# Memphis Grizzlies         18
# Miami Heat                15
# Milwaukee Bucks           16
# Minnesota Timberwolves    14
# New Orleans Pelicans      19
# New York Knicks           16
# Oklahoma City Thunder     15
# Orlando Magic             14
# Philadelphia 76ers        15
# Phoenix Suns              15
# Portland Trail Blazers    15
# Sacramento Kings          15
# San Antonio Spurs         15
# Toronto Raptors           15
# Utah Jazz                 16
# Washington Wizards        15
# Name: Name, dtype: int64

# %%
total=len(df)
total
# Out:
# 458

# %%
percentage=(uni/total)*100
percentage
# Out:
# Team
# Atlanta Hawks             3.275109
# Boston Celtics            3.275109
# Brooklyn Nets             3.275109
# Charlotte Hornets         3.275109
# Chicago Bulls             3.275109
# Cleveland Cavaliers       3.275109
# Dallas Mavericks          3.275109
# Denver Nuggets            3.275109
# Detroit Pistons           3.275109
# Golden State Warriors     3.275109
# Houston Rockets           3.275109
# Indiana Pacers            3.275109
# Los Angeles Clippers      3.275109
# Los Angeles Lakers        3.275109
# Memphis Grizzlies         3.930131
# Miami Heat                3.275109
# Milwaukee Bucks           3.493450
# Minnesota Timberwolves    3.056769
# New Orleans Pelicans      4.148472
# New York Knicks           3.493450
# Oklahoma City Thunder     3.275109
# Orlando Magic             3.056769
# Philadelphia 76ers        3.275109
# Phoenix Suns              3.275109
# Portland Trail Blazers    3.275109
# Sacramento Kings          3.275109
# ...

# %% [markdown]
# # 2.Sergregate the employees W.r,t different positions.

# %%
pos = df.groupby("Position")["Name"].unique()
pos
# Out:
# Position
# C     [Kelly Olynyk, Jared Sullinger, Tyler Zeller, ...
# PF    [Jonas Jerebko, Amir Johnson, Jordan Mickey, C...
# PG    [Avery Bradley, Terry Rozier, Marcus Smart, Is...
# SF    [Jae Crowder, Thanasis Antetokounmpo, Carmelo ...
# SG    [John Holland, R.J. Hunter, Evan Turner, James...
# Name: Name, dtype: object

# %% [markdown]
# # 3.Find from which age group most of the employees belong to

# %%
age=df.groupby("Age")["Name"].nunique()
age
# Out:
# Age
# 19     2
# 20    19
# 21    19
# 22    26
# 23    41
# 24    47
# 25    46
# 26    36
# 27    41
# 28    31
# 29    28
# 30    31
# 31    22
# 32    13
# 33    14
# 34    10
# 35     9
# 36    10
# 37     4
# 38     4
# 39     2
# 40     3
# Name: Name, dtype: int64

# %%
age_grp=age.idxmax()
age_grp
# Out:
# 24

# %%
print("The age where most number of employees belongs:",age_grp)
# Out:
# The age where most number of employees belongs: 24

# %% [markdown]
# # 4.Find out under which tem and positions , spending terms of salary is high.

# %%
pos=df.groupby(["Team","Position"])["Salary"].sum()
pos
# Out:
# Team                Position
# Atlanta Hawks       C           22756250.0
#                     PF          23952268.0
#                     PG           9763400.0
#                     SF           6000000.0
#                     SG          10431032.0
#                                    ...
# Washington Wizards  C           24490429.0
#                     PF          11300000.0
#                     PG          18022415.0
#                     SF          11158800.0
#                     SG          11356992.0
# Name: Salary, Length: 149, dtype: float64

# %%
max_spent=pos.idxmax()
max_spent
# Out:
# ('Los Angeles Lakers', 'SF')

# %% [markdown]
# # Loss Angles Lakers have the hieghest salary

# %% [markdown]
# 5.Find if therer is any correlation between age and represent it visual .

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df1 =df.drop(["Name","Team","Number","Position","Height","Weight","College"],axis="columns")
corr = df1.corr()
corr
sns.heatmap(corr,annot=True,cmap="coolwarm")
plt.title("Correlation between age and salary")
plt.show()

# %%
plt.scatter(df["Salary"],df["Age"],color="green")
plt.title("Correlation between age and salary")
plt.xlabel("Salary")
plt.ylabel("Age")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
